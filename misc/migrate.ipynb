# %%
import pandas as pd

# Specify the path to the Excel file
excel_file_path = "data.xlsx"

# Read the Excel file into a pandas DataFrame with row 0 as the header
df = pd.read_excel(excel_file_path, header=1)


df = df.fillna('')


df = df[df['Autor'] != ""]


print(df)
# Out:
#      Nr.                                Titel          Thema  \
# 0     39  Ein Vogel wollte Hochzeit feiern...           Spaß
# 1     20        Lies die Bibel, bet jeden Tag     Nachfolge
# 2     73        Lies die Bibel, bet jeden Tag     Nachfolge
# 3      4         Seht mal meinen Regenschirm   Gottes Schutz
# 4     47                    Ich und der Stuhl           Spaß
# ..   ...                                  ...            ...
# 190  184                   Das Lied über mich              ?
# 191  185            Ich habe eine Maus gesehn              ?
# 192  187            Du bist wunderbar gemacht              ?
# 193  189           Wäre ich ein Schmetterling              ?
# 194  190          Der Eisbär ging zum Eismann              ?
#
#                   Autor Bewegung Altersgruppe  Tonart  \
# 0    Ingeborg Meyer-Rey     Nein         Alle  G- Dur
# 1         Anton Schulte       Ja         Alle   D-Dur
# 2         Anton Schulte       Ja    3-6 Jahre   D-Dur
# 3    Margret Birkenfeld             4-6 Jahre   D-Dur
# 4            Grete Jalk       Ja  7-10 Jahre
# ..                  ...      ...          ...     ...
# 190                   ?                     ?
# 191                   ?                     ?
# 192                   ?                     ?
# 193                   ?                     ?
# 194                   ?                     ?
#
#                                         Besonderheiten Entstehungsjahr
# 0                             Die Hochzeit nachspielen             1470
# 1                                                                  1927
# 2                                Verschiedene Sprachen             1927
# 3                                                                  1956
# 4    Sprechgesang; man braucht dazu einen Stuhl und...             1963
# ..                                                 ...              ...
# 190                                                                   ?
# 191                                                                   ?
# 192                                                                   ?
# 193                                                                   ?
# 194                                                                   ?
#
# [195 rows x 9 columns]

# %%
import requests

# Set the base URL of your Strapi backend
base_url = "https://cms.frey-tech.de"

api_key = ""

# %%
unique_authors = df['Autor'].unique()



# Iterate over the "Autor" column
for author_name in unique_authors:
    # Define the data to send
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {api_key}"
    }


    data ={
        "data": {
            "name": author_name,
        }
    }

    # Send a POST request to the Strapi API
    response = requests.post(base_url + "/api/artists", json=data, headers=headers)

    # Check the response
    if response.status_code == 200:
        print(f'Successfully added author {author_name}')
    else:
        print(f'Failed to add author {author_name}. Response: {response.text}')
# Out:
# Failed to add author Ingeborg Meyer-Rey. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Anton Schulte. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Margret Birkenfeld. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Grete Jalk. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Paul Kuhn. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Arno Backhaus. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Magret Birkenfeld. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Pierre Kartner. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Ian Smale. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Gabriele Thalacker. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Michael Bewe. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Rolf Zuckowski. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Wolfgang Rahn. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Nena . Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Creme de la Creme. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Kinderchor Aidlingen. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Daniel Kallauch. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author DONIKKLs-Production. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Gerhard Schnitter. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Gerhard Schnitter; Daniel Fitz. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Johannes Kleiner. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Stephen Janetzko. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Markus Becker. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author ?. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Vince Barlow. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Simone Sommerland, Karsten Glück. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Elfi Bayer. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Feiert Jesus. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Sebastian Rochlitzer. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Rolf Zuckowski . Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Norbert Binder. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author John W. Peterson. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Alexandra Peter. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Claudia Horn . Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Andy Park, Daniel Kallauch. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Susan B. Warner, Edwin Othello Excell. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Dagmar Heizmann-Leucke, Klaus Heizmann. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Hella Heizmann. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Mike Müllerbauer. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Heike Schrader. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Wolfgang Longardt. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Peter Menger. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Ute Rink. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Christoph Zehendner, Daniel Kallauch. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Ilka Mix. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Lars Jacobsen Achim Oppermann. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Petra Halfmann. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Volker Rosin. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Simone Sommerland. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Detlev Jöcker. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Emmi Horstmann & Peter van Woerden. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Helga König. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Michael Noß. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Offenbach, Quarterhead. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Barbarossa Jävert. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Thomas Klein. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Martin Obert. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Alexander Lombardi. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Kathrin D. Weber. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Rolf Harris. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Simone Siegel. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Ute Rapsch, Jochen Rieger. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Nigel und Jo Hemming, Sarah Pickering. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Jana Alayra. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Abraham George. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Rolf Knetzer. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Rolf Knezer, Detlev Jürker. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Clemens Bittlinger. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Dallas Jenkin. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Christiane Dusza. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Marion und Gilbrecht Schäl. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Siegfried Uhlenbrock. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Achim Oppermann, Lars Jacobsen und Flo Bauer. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Heiner Rusche. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author G.+M. Schäl. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author P. Ehlebracht. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Regula Salathé/Larissa Zimmermeyer. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Susanna Lange. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Ute Spengler. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add author Vicky Preuss. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["name"],"message":"This attribute must be unique","name":"ValidationError"}]}}}

# %%
import requests



# Set the headers for the request
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_key}"
}

# Send a GET request to the authors endpoint
response = requests.get(base_url + "/api/artists?pagination[page]=1&pagination[pageSize]=90", headers=headers)

# Check the response
if response.status_code == 200:
    artists = response.json()
    artists = {artist["attributes"]['name']: artist['id'] for artist in artists["data"]}
    print(artists)
else:
    print(f'Failed to get authors. Response: {response.text}')
# Out:
# {'Ingeborg Meyer-Rey': 82, 'Anton Schulte': 83, 'Margret Birkenfeld': 84, 'Grete Jalk': 85, 'Paul Kuhn': 86, 'Arno Backhaus': 87, 'Magret Birkenfeld': 88, 'Pierre Kartner': 89, 'Ian Smale': 90, 'Gabriele Thalacker': 91, 'Michael Bewe': 92, 'Rolf Zuckowski': 93, 'Wolfgang Rahn': 94, 'Nena ': 95, 'Creme de la Creme': 96, 'Kinderchor Aidlingen': 97, 'Daniel Kallauch': 98, 'DONIKKLs-Production': 99, 'Gerhard Schnitter': 100, 'Gerhard Schnitter; Daniel Fitz': 101, 'Johannes Kleiner': 102, 'Stephen Janetzko': 103, 'Markus Becker': 104, '?': 105, 'Vince Barlow': 106, 'Simone Sommerland, Karsten Glück': 107, 'Elfi Bayer': 108, 'Feiert Jesus': 109, 'Sebastian Rochlitzer': 110, 'Rolf Zuckowski ': 111, 'Norbert Binder': 112, 'John W. Peterson': 113, 'Alexandra Peter': 114, 'Claudia Horn ': 115, 'Andy Park, Daniel Kallauch': 116, 'Susan B. Warner, Edwin Othello Excell': 117, 'Dagmar Heizmann-Leucke, Klaus Heizmann': 118, 'Hella Heizmann': 119, 'Mike Müllerbauer': 120, 'Heike Schrader': 121, 'Wolfgang Longardt': 122, 'Peter Menger': 123, 'Ute Rink': 124, 'Christoph Zehendner, Daniel Kallauch': 125, 'Ilka Mix': 126, 'Lars Jacobsen Achim Oppermann': 127, 'Petra Halfmann': 128, 'Volker Rosin': 129, 'Simone Sommerland': 130, 'Detlev Jöcker': 131, 'Emmi Horstmann & Peter van Woerden': 132, 'Helga König': 133, 'Michael Noß': 134, 'Offenbach, Quarterhead': 135, 'Barbarossa Jävert': 136, 'Thomas Klein': 137, 'Martin Obert': 138, 'Alexander Lombardi': 139, 'Kathrin D. Weber': 140, 'Rolf Harris': 141, 'Simone Siegel': 142, 'Ute Rapsch, Jochen Rieger': 143, 'Nigel und Jo Hemming, Sarah Pickering': 144, 'Jana Alayra': 145, 'Abraham George': 146, 'Rolf Knetzer': 147, 'Rolf Knezer, Detlev Jürker': 148, 'Clemens Bittlinger': 149, 'Dallas Jenkin': 150, 'Christiane Dusza': 151, 'Marion und Gilbrecht Schäl': 152, 'Siegfried Uhlenbrock': 153, 'Achim Oppermann, Lars Jacobsen und Flo Bauer': 154, 'Heiner Rusche': 155, 'G.+M. Schäl': 156, 'P. Ehlebracht': 157, 'Regula Salathé/Larissa Zimmermeyer': 158, 'Susanna Lange': 159, 'Ute Spengler': 160, 'Vicky Preuss': 161}

# %%
print(len(artists))
# Out:
# 80

# %%
import requests



# Iterate over the rows of the dataframe
for index, row in df.iterrows():
    # Get the values from the row
    song_name = row['Titel']
    artist_id = artists[row['Autor']]
    tags = row['Thema']
    
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {api_key}"
    }


    data ={
        "data": {
            "title": song_name,
            "artists": [artist_id],
            "tags": tags,
            "file": 1,
        }
    }

    # Send a POST request to the Strapi API
    response = requests.post(base_url + "/api/songs", json=data, headers=headers)

    # Check the response
    if response.status_code == 200:
        print(f'Successfully added Song {song_name}')
    else:
        print(f'Failed to add Song {song_name}. Response: {response.text}')
# Out:
# Failed to add Song Ein Vogel wollte Hochzeit feiern.... Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Lies die Bibel, bet jeden Tag. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Lies die Bibel, bet jeden Tag. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Seht mal meinen Regenschirm . Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Ich und der Stuhl. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Mein Dackel Waldemar und ich wir zwei.... Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Sing and pray. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Mach die Augen auf. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Ein kleines wildes Schäflein. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Sei ein lebendger Fisch . Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Ja, Gott hat alle Kinder lieb. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Pass auf, kleines Auge . Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Vater Abraham hat viele Kinder. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Mein Gott ist größer als die Berge. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Hast du den Mann aus Nazareth gesehen. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Sing mit mir ein Halleluja. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Komm mit, komm mit, wir suchen einen Schatz. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song In der Weihnachtsbäckerei. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Hast du heute schon Danke gesagt. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Jesus Christus ist der Sieger. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Ja, Herr ich freu mich so. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Gott hat unsere Erde schön gemacht. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Schneeflöckchen, Weißröckchen . Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Drei Chinesen mit dem Kontrabass. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Wer lässt die Sterne strahlen. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Ich bin ein Bibelentdecker . Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Der Kluge baut sein Haus. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Fliegerlied. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Vom Anfang bis zum Ende. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Nichts, nichts kann uns trennen. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Bist du groß oder bist du klein . Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Danke, Danke, Danke . Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Das rote Pferd. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Die Affen rasen durch den Wald. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Einfach Spitze. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Hast du heute schon danke gesagt . Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Failed to add Song Ich stehe fest auf dem Fels. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Successfully added Song 10 kleine Zappelmänner
# Successfully added Song Hallo, Hallo, schön, dass du da bist
# Successfully added Song Meine Hände sind verschwunden
# Successfully added Song Sommer, Sonne, Ferienzeit
# Successfully added Song Wir räumen jetzt zusammen auf
# Successfully added Song Tante aus Marokko
# Successfully added Song Kindermutmachlied
# Successfully added Song Schmetterling, du kleines Ding
# Successfully added Song Ich bin ein dicker Tanzbär
# Successfully added Song Hallo ciao ciao guten Tag moin moin
# Successfully added Song Ich streck mich aus
# Successfully added Song Zwei kleine Wölfe
# Successfully added Song Jesus nur er
# Successfully added Song Er ist links er ist rechts
# Successfully added Song Ich bin von innen außen oben unten
# Successfully added Song Wenn du glücklich bist, dann klatsche in die Hand
# Successfully added Song Hör, die Vögel singen gern
# Successfully added Song Mein Gott ist so groß
# Successfully added Song Superduperspitzenklasse
# Successfully added Song Du hast uns deine Welt geschenkt
# Successfully added Song Stop, und lass dir sagen
# Successfully added Song 5 kleine Fische
# Successfully added Song Gottes große Liebe
# Successfully added Song Felsenfest und stark
# Successfully added Song Jesus heißt uns leuchten
# Successfully added Song Durch die Straßen auf und nieder
# Successfully added Song Singt, seid froh, denn Jesus ist am Leben
# Successfully added Song Ja so ein Zimmer, das ist ein Instrument
# Successfully added Song Jesus kam für dich
# Successfully added Song Vielen Dank für die Sonne
# Successfully added Song Ein dickes Dankeschön
# Successfully added Song Wie kommt das Brot auf unsern Tisch
# Successfully added Song Ich lieb den Frühling
# Successfully added Song Immer wieder kommt ein neuer Frühling
# Successfully added Song Tragt in die Welt nun ein Licht
# Successfully added Song Ich geh mit meiner Laterne
# Successfully added Song Meine Mama ist mein bester Freund
# Successfully added Song Stubs der kleine Osterhase
# Successfully added Song Gott mag Farben
# Successfully added Song Gottes Welt
# Successfully added Song Adventskrankkerzenglanz
# Successfully added Song Ein tolles Fest
# Successfully added Song Das größte Geschenk
# Successfully added Song Alle kleinen Tiere
# Successfully added Song Hallo, hallo, hallo, wenn wir uns treffen, sind wir froh
# Successfully added Song Wenn wir uns begrüßen
# Successfully added Song Von morgens bis zum Mittag
# Successfully added Song Wir sitzen in Kreis
# Successfully added Song Halli hallo herzlich willkommen
# Successfully added Song Hallo Du
# Successfully added Song Ich will euch begrüßen und mache es so (mit verschiedenen Sprachen begrüßen)
# Successfully added Song Sali Bonani
# Successfully added Song Gottes Liebe ist so wunderbar
# Successfully added Song Ein kleines wildes Schäfchen
# Successfully added Song Lasst uns miteinander
# Failed to add Song Mach die Augen auf. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Successfully added Song Die Sonne, die Erde, die Wolken
# Successfully added Song Du bist da wo Menschn leben
# Successfully added Song Wenn der Herbst Geschenke macht
# Successfully added Song Laterne, Laterne
# Successfully added Song 12345678910, jetzt wird nicht zuhaus geblieben
# Successfully added Song Voll-, Voll-, Volltreffer
# Failed to add Song Mein Gott ist so groß. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Successfully added Song Ein kleiner grauer Esel
# Successfully added Song Eins, zwei, der Herr ist treu
# Successfully added Song Das Fischlein in dem Wasser
# Successfully added Song Bist du groß oder bist du klein
# Successfully added Song Gott braucht nicht nur große Leute
# Successfully added Song Hand and Shoulders, Knees and Toes
# Successfully added Song Hallelu-, Hallelu-, Hallelu-, Halleluja, preiset den Herrn
# Successfully added Song Er hält die ganze Welt
# Successfully added Song Die Jahresuhr
# Successfully added Song Feuerwerk
# Successfully added Song Gott ist unser Vater
# Successfully added Song Gott unser Vater
# Successfully added Song Ich schleuder, schleuder, schleuder
# Successfully added Song Keine Angst
# Successfully added Song Du bist stark, stark, stark, du bist der größte (Adlersong)
# Successfully added Song Hallo Herbst
# Successfully added Song Es ist Herbst
# Successfully added Song Bunte Blätter
# Successfully added Song Du bist der Hirte
# Successfully added Song Liebe Gott und deinen Nächsten
# Successfully added Song Alles war deine Idee
# Successfully added Song Halt das Känguru fest
# Successfully added Song Mein Gott vergibt gern
# Successfully added Song Bücherhelden
# Successfully added Song Danke, ich freu mich, Gott sorgt für mich an jedem Tag
# Successfully added Song Suche den Frieden
# Successfully added Song Gott will mit dir reden
# Successfully added Song Rundherum
# Successfully added Song Nie, nie, nie vergess ich (Mach die Augen auf)
# Successfully added Song So glad
# Successfully added Song Sei mutig und stark und fürchte dich nicht
# Successfully added Song Regen gibt hier
# Successfully added Song Jesus is the winnerman
# Successfully added Song Komm, sag es allen weiter
# Successfully added Song Freundlich sein macht Freude
# Successfully added Song Kaugummi
# Successfully added Song Vater unser im Himmel
# Successfully added Song Jesus das ist alles was wir haben
# Successfully added Song Zum Geburtstag kommen wir
# Successfully added Song Weil du heut Geburtstag hast
# Successfully added Song Der Herbst ist da
# Successfully added Song Und so geh nun deinen Weg
# Successfully added Song Oh du fröhliche
# Successfully added Song Jesus liebt die Kinder
# Failed to add Song Gottes Liebe ist so wunderbar. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Successfully added Song Ich freu mich auf den Tag
# Successfully added Song Heute kann es regnen,stürmen oder schnein
# Successfully added Song Deep down in my heart
# Successfully added Song Sag mir wie Gott ist
# Successfully added Song Gott mag Kinder
# Successfully added Song Da staunst du
# Successfully added Song Von oben, von unten
# Successfully added Song Der PiPaPutzige Igel
# Successfully added Song Der Herr ist mein Hirte und ich bin sein Schäfchen
# Successfully added Song Lichterkinder
# Successfully added Song Jeden Schritt
# Successfully added Song Aufräumkönig
# Successfully added Song Er lebt
# Successfully added Song Lass das Lied der Liebe weiterklingen
# Successfully added Song Komm wir gehn nach Betlehem
# Successfully added Song Stern über Betlehem
# Successfully added Song Stille Nacht, heilige Nacht
# Successfully added Song Ja, dann ist Advent
# Successfully added Song Komm wir schauen in das Licht
# Successfully added Song Du bist und bleibst einmalig
# Successfully added Song Megaspaß
# Successfully added Song Mein Gott ist spitze
# Successfully added Song Freundschaft
# Successfully added Song Psalmen sind Lieder aus uralten Zeiten
# Successfully added Song Der Papagei ein Vogel ist
# Successfully added Song Je-, Je-, Jesus ist größer
# Successfully added Song Von oben und von unten
# Successfully added Song Gott ist stark
# Successfully added Song Sprüche 6,6-11
# Successfully added Song Gummibär
# Successfully added Song Dip, Dip
# Successfully added Song In Gottes Haus
# Successfully added Song An meinem Fahrrad ist alles dran
# Successfully added Song Jede Menge Töne
# Successfully added Song Mir geht ein Licht auf
# Successfully added Song Miteinander wunderbar
# Successfully added Song This little light of mine
# Successfully added Song Er ist der Beste, den es gibt
# Successfully added Song Du und ich wir sind ein Königskind
# Successfully added Song Mose
# Successfully added Song Neu, neu, neu
# Successfully added Song Mein ganzes Herz
# Successfully added Song Du bist spitze, du bist genial
# Failed to add Song Gottes große Liebe. Response: {"data":null,"error":{"status":400,"name":"ValidationError","message":"This attribute must be unique","details":{"errors":[{"path":["title"],"message":"This attribute must be unique","name":"ValidationError"}]}}}
# Successfully added Song Sei einfach du
# Successfully added Song Das Lied über mich
# Successfully added Song Ich habe eine Maus gesehn
# Successfully added Song Du bist wunderbar gemacht
# Successfully added Song Wäre ich ein Schmetterling
# Successfully added Song Der Eisbär ging zum Eismann

# %%
import requests



# Set the headers for the request
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_key}"
}

# Send a GET request to the authors endpoint
response = requests.get(base_url + "/api/songs?populate=*", headers=headers)

# Check the response
if response.status_code == 200:
    songs = response.json()
    
    print(songs)
else:
    print(f'Failed to get authors. Response: {response.text}')
# Out:
# {'data': [{'id': 1, 'attributes': {'title': 'Test Song', 'lyrics': "Can't keep my hands to myself\nThink I'll dust 'em off, put 'em back up on the shelf\nIn case my little baby girl is in need\nAm I coming out of left field?\nOoh woo, I'm a rebel just for kicks, now\nI been feeling it since 1966, now\nMight be over now, but I feel it still\nOoh woo, I'm a rebel just for kicks, now\nLet me kick it like it's 1986, now\nMight be over now, but I feel it still\nGot another mouth to feed\nLeave her with a baby sitter, mama, call the grave digger\nGone with the fallen leaves\nAm I coming out of left field?\nOoh woo, I'm a rebel just for kicks, now\nI been feeling it since 1966, now\nMight've had your fill, but you feel it still\nOoh woo, I'm a rebel just for kicks, now\nLet me kick it like it's 1986, now\nMight be over now, but I feel it still\nWe could fight a war for peace\n(Ooh woo, I'm a rebel just for kicks, now)\nGive in to that easy living\nGoodbye to my hopes and dreams\nStop flipping for my enemies\nWe could wait until the walls come down\n(Ooh woo, I'm a rebel just for kicks, now)\nIt's time to give a little to the\nKids in the middle, but oh 'til it falls\nWon't bother me\nIs it coming?\nIs it coming?\nIs it coming?\nIs it coming?\nIs it coming?\nIs it coming back?\nOoh woo, I'm a rebel just for kicks, yeah\nYour love is an abyss for my heart to eclipse, now\nMight be over now, but I feel it still\nOoh woo, I'm a rebel just for kicks, now\nI've been feeling it since 1966, now\nMight be over now, but I feel it still\nOoh woo, I'm a rebel just for kicks, now\nLet me kick it like it's 1986, now\nMight be over now, but I feel it still\nMight've had your fill, but you feel it still", 'createdAt': '2023-12-27T13:29:53.825Z', 'updatedAt': '2024-02-12T19:51:39.721Z', 'tags': None, 'minAge': None, 'maxAge': None, 'file': {'data': {'id': 2, 'attributes': {'name': 'Praise-and-Worship-Book-WITH-CHORDS.pdf', 'alternativeText': None, 'caption': None, 'width': None, 'height': None, 'formats': None, 'hash': 'Praise_and_Worship_Book_WITH_CHORDS_65e384a5a4', 'ext': '.pdf', 'mime': 'application/pdf', 'size': 758.81, 'url': '/uploads/Praise_and_Worship_Book_WITH_CHORDS_65e384a5a4.pdf', 'previewUrl': None, 'provider': 'local', 'provider_metadata': None, 'createdAt': '2023-12-26T18:18:45.448Z', 'updatedAt': '2023-12-29T11:02:14.175Z'}}}, 'artists': {'data': []}}}], 'meta': {'pagination': {'page': 1, 'pageSize': 25, 'pageCount': 1, 'total': 1}}}
